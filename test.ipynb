# %%
# 打開文件
frequency_magnitude = []
frequency_phase = []
with open('TT.txt', 'r', encoding='utf-8') as file:
    # 讀取整個文件
    content = file.read()

print(content)

# %%
import numpy as np
import scipy.io.wavfile as wavfile
import matplotlib.pyplot as plt

# 讀取WAV文件
filename = 'WAV-INPUT.wav'
sample_rate, data1 = wavfile.read(filename)
data1 = data1/max(data1)

filename2 = 'WAV-OUTPUT.wav'
sample_rate, data2 = wavfile.read(filename2)
data2 = data2/max(data2)

output = np.correlate(data2,data1,mode='same')
print(output)
#output /= max(output)


# # 繪製頻譜圖
# plt.figure(figsize=(10, 6))
plt.plot(output)
# plt.title('Frequency Spectrum')
# plt.xlabel('Frequency (Hz)')
# plt.ylabel('Amplitude')
# plt.xscale('log')
# plt.grid()
plt.plot(output)
# Out:
# [-19.32495646  -3.06172193  -5.45022995 ...   4.67331349   7.65688741
#    7.4641073 ]

# %%
plt.plot(data1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(output[A:A+500])
plt.show()

# %%
Test0 = np.fft.fft(output[A:A+500])
yf_amplitude = np.abs(Test0[:len(Test0)//2])
yf_amplitude = 20 * np.log(yf_amplitude)
print(len(Test0))
plt.plot(yf_amplitude)
plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# 500

# %%
A = np.argmax(output)
print(A)
# Out:
# 22050

# %%
np.correlate
# Out:
# <function numpy.correlate(a, v, mode='valid')>

# %%
yf_original = yf_original[:44100]
print(len(yf_original))
print(yf_original)
print('impulse_response',impulse_response)
# Out:
# 44100
# [  -603922.1953125 +9.31322575e-10j   -850806.83358093+8.73605842e+04j
#    -767945.04938221-2.13584033e+05j ...  -3404837.25758844+8.14646456e+06j
#    4682709.64111904+2.08047310e+06j -14623202.75153218-3.90332523e+06j]
# impulse_response [  784.53789124  4881.45975502  3029.31178508 ... -1978.74487744
#  -2554.61137136 -1781.47323708]

# %%
from numpy.fft import irfft
impulse_response = irfft(yf_original)
# 繪製頻譜圖

plt.plot(impulse_response)
